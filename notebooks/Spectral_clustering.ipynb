# %%
import sys
if '..' not in sys.path:
    sys.path.insert(0, '..')

import pandas as pd
#import govcxanalyzer.spclus_utils as spc
import GovCXAnalyzer.spclus_utils as spc
# Out:
# /Users/samueljthomas/repos/genv/lib/python3.9/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/samueljthomas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
videogames = pd.read_csv('../data/example-video-game-reviews.csv')

# %%
videogames.shape
# Out:
# (8000, 12)

# %%
xcols = ['reviewText', 'summary']

# %%
sclus = spc.SpecClustering(min_doc_tfidf = 50,
                           max_doc_tfidf = 0.40)
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/samueljthomas/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
sclus.fit_predict(videogames[xcols])
# Out:
# /Users/samueljthomas/repos/genv/lib/python3.9/site-packages/sklearn/manifold/_spectral_embedding.py:329: UserWarning: Graph is not fully connected, spectral embedding may not work as expected.
#   warnings.warn(

# %%
pd.Series(sclus.k).value_counts()
# Out:
# 8     4550
# 2      975
# 12     945
# 1      458
# 6      365
# 7      317
# 10     286
# 5       39
# 11      26
# 3       20
# 9       15
# 4        4
# Name: count, dtype: int64

# %%
sclus.plot(ptype='eigenvalues', num_eigenvalues=100)

# %%
sclus.plot()
